# %%
# Question 1
# 1. Define a doubly linked list  [ Will be done in the class ]
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current

    def display(self):
        current = self.head
        if not current:
            print("The list is empty.")
            return
        while current:
            print(current.data, end="")
            if current.next:
                print(" <-> ", end="")
            current = current.next
        print()

# Example usage
dll = DoublyLinkedList()

dll.append(1)
dll.append(2)
dll.append(3)
dll.append(4)

print("Doubly linked list:")
dll.display()
# Out:
# Doubly linked list:
# 1 <-> 2 <-> 3 <-> 4

# %% [markdown]
# This Python code defines and demonstrates a simple implementation of a doubly linked list in Python. A doubly linked list is a data structure consisting of nodes where each node contains a reference to both its previous and next nodes, allowing traversal in both directions.
#
# Here's a explaination of the code:
#
# 1.Node Creation: Each node in the list is an instance of the Node class. It stores the node's data and has two pointers: one for the previous node (prev) and one for the next node (next).
#
# 2.DoublyLinkedList Initialization: The DoublyLinkedList class initializes with a head pointer, which is set to None initially, indicating that the list is empty.
#
# 3.Appending Nodes:
#
# 3.1.When a new node is appended, if the list is empty (i.e., head is None), the new node becomes the head of the list.
#
# 3.2.If the list is not empty, the code traverses to the end of the list by following the next pointers and adds the new node there. The new node's prev pointer is updated to point to the previous last node.
#
# 4.Displaying Nodes:
#
# 4.1.To display the list, the code starts at the head and traverses through each node, printing its data.
#
# 4.2.Between nodes, it prints a " <-> " to indicate the connection between them.
#
# 4.3.When the end of the list is reached, it prints a newline to finish the output.
#
# 5.Example Usage:
#
# 5.1.An instance of DoublyLinkedList is created.
#
# 5.2.Several nodes are appended to the list with values 1, 2, 3, and 4.
#
# 5.3.The display method is called to print the list, showing nodes connected by arrows.

# %%
# Question 2
# 2. Write a function to reverse a linked list in-place
class ListNode:
    def __init__(self, value=0, next=None):
        self.value = value
        self.next = next

def reverse_linked_list(head):
    prev = None
    current = head

    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node

    return prev

def print_linked_list(head):
    current = head
    while current:
        print(current.value, end=" -> ")
        current = current.next
    print("None")

# Creating the linked list: 1 -> 2 -> 3 -> 4
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)

print("Original Linked List:")
print_linked_list(head)

# Reversing the linked list
head = reverse_linked_list(head)

print("Reversed Linked List:")
print_linked_list(head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> None
# Reversed Linked List:
# 4 -> 3 -> 2 -> 1 -> None

# %% [markdown]
# This Python code defines and demonstrates how to reverse a singly linked list in-place. Reversing a linked list means changing the direction of the pointers so that the list order is reversed.
#
# Here’s how the code works:
#
# 1.ListNode Creation:
#
# 1.1.Nodes are created using the ListNode class, where each node has a value and a next pointer.
#
# 1.2.The list 1 -> 2 -> 3 -> 4 is set up by linking nodes together.
#
# 2.Reversing the Linked List:
#
# 2.1.The reverse_linked_list function initializes two pointers: prev (set to None) and current (set to the head of the list).
#
# 2.2.It iterates through the list, adjusting each node’s next pointer to point to the previous node.
#
# 2.3.The prev pointer moves forward to become the new head of the list when the end is reached.
#
# 3.Printing the Linked List:
# The print_linked_list function starts from the head and prints each node’s value followed by an arrow (->) until it reaches the end, then prints None.
#
# 4.Example Usage:
#
# 4.1.The original linked list is created and printed, showing the order 1 -> 2 -> 3 -> 4.
#
# 4.2.The list is then reversed using the reverse_linked_list function.
#
# 4.3.The reversed list is printed, showing the order 4 -> 3 -> 2 -> 1.

# %%
# Question 3
# 3. Detect cycle in a linked list
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def has_cycle(head):
    if not head or not head.next:
        return False

    slow = head
    fast = head

    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            return True

    return False

# Creating a linked list: 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> (back to 3, forming a cycle)
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)
head.next.next.next.next.next = ListNode(6)
head.next.next.next.next.next.next = head.next.next  # Creating a cycle

print("Does the linked list have a cycle?", has_cycle(head))
# Out:
# Does the linked list have a cycle? True

# %% [markdown]
# This Python code checks if a linked list contains a cycle. A cycle in a linked list occurs when a node’s next pointer refers back to a previous node, forming a loop.
#
# Here’s a breakdown of how the code works:
#
# 1.ListNode Creation:
#
# 1.1.Nodes are created using the ListNode class, with each node pointing to the next in the sequence.
#
# 1.2.The list 1 -> 2 -> 3 -> 4 -> 5 -> 6 is created with a cycle where node 6 points back to node 3.
#
# 2.Cycle Detection:
#
# 2.1.The has_cycle function initializes two pointers: slow and fast, both starting at the head of the list.
#
# 2.2.The slow pointer advances one step at a time, while the fast pointer advances two steps at a time.
#
# 2.3.If a cycle exists, the slow and fast pointers will eventually meet inside the cycle.
#
# 2.4.If the pointers do not meet and the fast pointer reaches the end of the list, there is no cycle.
#
# 3.Example Usage:
#
# 3.1.A linked list is set up with a cycle by making node 6 point back to node 3.
#
# 3.2.The has_cycle function is called to check if the list contains a cycle.
#
# 3.3.The result, True or False, indicates whether a cycle is present.

# %%
# Question 4
# 4. Merge two sorted linked list into one
# 1->3->5->6->null and 2->4->6->8->null should be merged to make 1->2->3->4->5->6->7->8
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def merge_sorted_lists(l1, l2):
    dummy = ListNode()  # Dummy node to simplify the merge process
    current = dummy

    while l1 and l2:
        if l1.value < l2.value:
            current.next = l1
            l1 = l1.next
        else:
            current.next = l2
            l2 = l2.next
        current = current.next

    # Attach the remaining nodes from l1 or l2
    if l1:
        current.next = l1
    elif l2:
        current.next = l2

    return dummy.next

def print_linked_list(head):
    current = head
    while current:
        print(current.value, end=" -> ")
        current = current.next
    print("None")

# Creating two sorted linked lists
l1 = ListNode(1)
l1.next = ListNode(3)
l1.next.next = ListNode(5)
l1.next.next.next = ListNode(7)

l2 = ListNode(2)
l2.next = ListNode(4)
l2.next.next = ListNode(6)
l2.next.next.next = ListNode(8)

print("Original Linked List 1:")
print_linked_list(l1)

print("Original Linked List 2:")
print_linked_list(l2)

# Merging the two sorted linked lists
merged_list = merge_sorted_lists(l1, l2)

print("Merged Linked List:")
print_linked_list(merged_list)
# Out:
# Original Linked List 1:
# 1 -> 3 -> 5 -> 7 -> None
# Original Linked List 2:
# 2 -> 4 -> 6 -> 8 -> None
# Merged Linked List:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7 -> 8 -> None

# %% [markdown]
# This Python code merges two sorted linked lists into a single sorted linked list. It uses a dummy node to simplify the merging process.
#
# Here’s a breakdown of how the code works:
#
# 1.ListNode Creation:
# Nodes are created using the ListNode class for each list. The first list (l1) contains nodes with values 1 -> 3 -> 5 -> 7, and the second list (l2) contains nodes with values 2 -> 4 -> 6 -> 8.
#
# 2.Merging Sorted Lists:
#
# 2.1.The merge_sorted_lists function starts by creating a dummy node to simplify the merging process and initializes a current pointer to the dummy node.
#
# 2.2.It iterates through both lists, comparing the current nodes of l1 and l2. The smaller value is added to the merged list, and the pointer for that list is advanced.
#
# 2.3.After the iteration, if there are remaining nodes in either l1 or l2, they are attached to the end of the merged list.
#
# 2.4.The function returns dummy.next, which points to the head of the newly merged sorted list.
#
# 3.Printing the Linked List:
# The print_linked_list function traverses the linked list starting from the head, printing each node’s value followed by an arrow (->) until it reaches the end, then prints None.
#
# 4.Example Usage:
#
# 4.1.Two sorted linked lists (l1 and l2) are created and printed.
#
# 4.2.The merge_sorted_lists function merges these two lists into one sorted list.
#
# 4.3.The merged list is printed, showing the combined and sorted values from both original lists.

# %%
# Question 5
# 5. Write a function to remove nth node from the end in a linked list
# 1->2->3->4->5->6, removing 2nd node from end will return 1->2->3->4->6
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def remove_nth_from_end(head, n):
    dummy = ListNode()
    dummy.next = head
    slow = dummy
    fast = dummy

    # Move fast ahead by n + 1 steps
    for _ in range(n + 1):
        fast = fast.next

    # Move both pointers until fast reaches the end
    while fast:
        slow = slow.next
        fast = fast.next

    # Skip the nth node from the end
    slow.next = slow.next.next

    return dummy.next

def print_linked_list(head):
    current = head
    while current:
        print(current.value, end=" -> ")
        current = current.next
    print("None")

# Creating the linked list: 1 -> 2 -> 3 -> 4 -> 5 -> 6
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)
head.next.next.next.next.next = ListNode(6)

print("Original Linked List:")
print_linked_list(head)

# Removing 2nd node from end
head = remove_nth_from_end(head, 2)

print("Linked List after removing 2nd node from end:")
print_linked_list(head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> None
# Linked List after removing 2nd node from end:
# 1 -> 2 -> 3 -> 4 -> 6 -> None

# %% [markdown]
# This Python code removes the nth node from the end of a linked list. It uses a two-pointer technique to find and remove the specified node efficiently.
#
# Here’s how the code works:
#
# 1.ListNode Creation:
# Nodes are created using the ListNode class, resulting in a linked list with the values 1 -> 2 -> 3 -> 4 -> 5 -> 6.
#
# 2.Removing nth Node from End:
#
# 2.1.The remove_nth_from_end function starts by creating a dummy node pointing to the head of the list. This helps simplify edge cases, such as removing the head node.
#
# 2.2.Two pointers, slow and fast, are initialized at the dummy node.
#
# 2.3.The fast pointer is moved n + 1 steps ahead to ensure the gap between slow and fast is n nodes.
#
# 2.4.Both pointers are then moved together until the fast pointer reaches the end of the list. At this point, the slow pointer is just before the node to be removed.
#
# 2.5.The node to be removed is skipped by adjusting the next pointer of the slow node to point to the node after the node to be removed.
#
# 2.6.The function returns dummy.next, which is the head of the modified list.
#
# 3.Printing the Linked List:
# The print_linked_list function traverses the linked list starting from the head, printing each node’s value followed by an arrow (->) until it reaches the end, then prints None.
#
# 4.Example Usage:
#
# 4.1.The linked list 1 -> 2 -> 3 -> 4 -> 5 -> 6 is created and printed.
#
# 4.2.The remove_nth_from_end function is called to remove the 2nd node from the end, which is node 5.
#
# 4.3.The updated list is printed, showing 1 -> 2 -> 3 -> 4 -> 6.

# %%
# Question 6
# 6. Remove duplicates from a sorted linked list
# 1->2->3->3->4->4->4->5  should be changed to 1->2->3->4->5
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def remove_duplicates(head):
    current = head

    while current and current.next:
        if current.value == current.next.value:
            current.next = current.next.next
        else:
            current = current.next

    return head

def print_linked_list(head):
    current = head
    while current:
        print(current.value, end=" -> ")
        current = current.next
    print("None")

# Creating the linked list: 1 -> 2 -> 3 -> 3 -> 4 -> 4 -> 4 -> 5
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(3)
head.next.next.next.next = ListNode(4)
head.next.next.next.next.next = ListNode(4)
head.next.next.next.next.next.next = ListNode(4)
head.next.next.next.next.next.next.next = ListNode(5)

print("Original Linked List with duplicates:")
print_linked_list(head)

# Removing duplicates
head = remove_duplicates(head)

print("Linked List after removing duplicates:")
print_linked_list(head)
# Out:
# Original Linked List with duplicates:
# 1 -> 2 -> 3 -> 3 -> 4 -> 4 -> 4 -> 5 -> None
# Linked List after removing duplicates:
# 1 -> 2 -> 3 -> 4 -> 5 -> None

# %% [markdown]
# This Python code removes duplicate nodes from a sorted linked list. Since the list is sorted, duplicates will be adjacent.
#
# Here’s a breakdown of how the code works:
#
# 1.ListNode Creation:
# Nodes are created using the ListNode class, resulting in a linked list with the values 1 -> 2 -> 3 -> 3 -> 4 -> 4 -> 4 -> 5.
#
# 2.Removing Duplicates:
#
# 2.1.The remove_duplicates function starts by initializing the current pointer at the head of the list.
#
# 2.2.It iterates through the list, checking if the value of the current node is the same as the value of the current.next node.
#
# 2.3.If they are the same (indicating a duplicate), the current.next pointer is updated to skip the duplicate node (current.next = current.next.next).
#
# 2.4.If they are not the same, the current pointer is advanced to the next node.
#
# 2.5.This process continues until the end of the list is reached.
#
# 2.6.The function returns the head of the modified list.
#
# 3.Printing the Linked List:
#
# The print_linked_list function traverses the linked list starting from the head, printing each node’s value followed by an arrow (->) until it reaches the end, then prints None.
#
# 4.Example Usage:
#
# 4.1.The linked list 1 -> 2 -> 3 -> 3 -> 4 -> 4 -> 4 -> 5 is created and printed.
#
# 4.2.The remove_duplicates function is called to remove duplicate nodes, resulting in the list 1 -> 2 -> 3 -> 4 -> 5.
#
# 4.3.The updated list is printed, showing the list with duplicates removed.

# %%
# Question 7
# 7. Find the intersection of the two linked lists
# 1->2->3->4->8->6->9  5->1->6->7  , intersection 1->6
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def has_intersection(headA, headB):
    # Use a set to store nodes from the first list
    nodes_in_listA = set()
    
    # Traverse the first list and store nodes in the set
    current = headA
    while current:
        nodes_in_listA.add(current)
        current = current.next
    
    # Traverse the second list and check for intersection
    current = headB
    while current:
        if current in nodes_in_listA:
            return True
        current = current.next
    
    return False

# Create the first linked list: 1 -> 2 -> 3 -> 4 -> 8 -> 6 -> 9
headA = ListNode(1)
headA.next = ListNode(2)
headA.next.next = ListNode(3)
headA.next.next.next = ListNode(4)
headA.next.next.next.next = ListNode(8)
intersection = ListNode(6)
headA.next.next.next.next.next = intersection
intersection.next = ListNode(9)

# Create the second linked list: 5 -> 1 -> 6 -> 7
headB = ListNode(5)
headB.next = ListNode(1)
headB.next.next = intersection
headB.next.next.next = ListNode(7)

# Check for intersection
intersection_exists = has_intersection(headA, headB)

print("Intersection Exists:", intersection_exists)
# Out:
# Intersection Exists: True

# %% [markdown]
# This Python code determines whether two linked lists intersect and, if so, checks if there are common nodes between the two lists.
#
# Here's a breakdown of how the code works:
#
# 1.ListNode Creation:
#
# 1.1.Nodes are created using the ListNode class to form two linked lists:
#
# 1.2.List A: 1 -> 2 -> 3 -> 4 -> 8 -> 6 -> 9
#
# 1.3.List B: 5 -> 1 -> 6 -> 7
#
# 1.4.The intersection node 6 is shared by both lists.
#
# 2.Checking for Intersection:
#
# 2.1.The has_intersection function initializes a set called nodes_in_listA to store nodes from the first linked list.
#
# 2.2.It traverses the first list (headA), adding each node to the set.
#
# 2.3.It then traverses the second list (headB), checking if any node in this list is also present in the set (nodes_in_listA).
#
# 2.4.If a node from the second list is found in the set, it indicates an intersection, and the function returns True.
#
# 2.5.If no common node is found after traversing the second list, the function returns False.
#
# 3.Example Usage:
#
# 3.1.Two linked lists are created with the intersection node 6.
#
# 3.2.The has_intersection function is called to check if there is an intersection between the two lists.
#
# 3.3.The result (True in this case) indicates that the two lists intersect at node 6.

# %%
# Question 8
# 8. Rotate a linked list by k positions to the right
# 1->2->3->4->8->6->9 , after rotating for 2 times becomes , 3->4->8->6->9->1->2
class ListNode:
    def __init__(self, value=0):
        self.value = value
        self.next = None

def rotate_right(head, k):
    if not head or k == 0:
        return head

    # Find the length of the linked list and the tail
    length = 1
    old_tail = head
    while old_tail.next:
        old_tail = old_tail.next
        length += 1

    # Calculate the effective rotation
    k = k % length
    if k == 0:
        return head

    # Find the new tail and new head
    new_tail_position = k - 1
    new_tail = head
    for _ in range(new_tail_position):
        new_tail = new_tail.next

    new_head = new_tail.next

    # Update the links to rotate the list
    old_tail.next = head
    new_tail.next = None

    return new_head

def print_linked_list(head):
    current = head
    while current:
        print(current.value, end=" -> ")
        current = current.next
    print("None")

# Create the linked list: 1 -> 2 -> 3 -> 4 -> 8 -> 6 -> 9
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(8)
head.next.next.next.next.next = ListNode(6)
head.next.next.next.next.next.next = ListNode(9)

print("Original Linked List:")
print_linked_list(head)

# Rotate the linked list by 2 positions to the left
rotated_head = rotate_right(head, 2)

print("Linked List after rotating by 2 positions to the right:")
print_linked_list(rotated_head)
# Out:
# Original Linked List:
# 1 -> 2 -> 3 -> 4 -> 8 -> 6 -> 9 -> None
# Linked List after rotating by 2 positions to the right:
# 3 -> 4 -> 8 -> 6 -> 9 -> 1 -> 2 -> None

# %% [markdown]
# This Python code rotates a linked list by k positions to the right.
#
# Here’s how it works:
#
# 1.ListNode Creation:
# Nodes are created using the ListNode class to form a linked list: 1 -> 2 -> 3 -> 4 -> 8 -> 6 -> 9.
#
# 2.Find List Length and Tail:
#
# 2.1.The rotate_right function starts by determining the length of the list and identifying the tail node.
#
# 2.2.It traverses the list from the head to the end, counting the nodes and keeping a reference to the tail node.
#
# 3.Effective Rotation Calculation:
#
# 3.1.The effective rotation is calculated using k % length to handle cases where k is greater than the list length.
#
# 3.2.If the effective rotation k is 0, the list is returned as-is, since rotating by the length of the list results in no change.
#
# 4.Find New Tail and Head:
#
# 4.1.To determine the new head after rotation, the function identifies the new tail node. This is done by moving k-1 steps from the head.
#
# 4.2.The new head is the node immediately after the new tail.
#
# 5.Update Links:
#
# 5.1.The function updates the links to perform the rotation:
#
# 5.1.1.The current tail’s next pointer is set to the original head, forming a circular link.
#
# 5.1.2.The new tail’s next pointer is set to None, breaking the circle and setting the new end of the list.
#
# 6.Example Usage:
#
# 6.1.The linked list is created and then rotated by 2 positions to the right using the rotate_right function.
#
# 6.2.The rotated list is printed, showing the result after rotation: 3 -> 4 -> 8 -> 6 -> 9 -> 1 -> 2.

# %%
# Question 9
# 9. Add Two Numbers Represented by LinkedLists:
# Given two non-empty linked lists representing two non-negative integers, where the digits are stored in reverse order,
# add the two numbers and return it as a linked list.
# Linked List Node
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Handle list operations
class LinkedList:
    def __init__(self):
        self.head = None

    # Method to traverse list and return it in a format
    def traverse(self):
        linkedListStr = ""
        temp = self.head
        while temp:
            linkedListStr += str(temp.data) + " -> "
            temp = temp.next
        return linkedListStr + "NULL"

    # Method to insert data in linked list
    def insert(self, data):
        newNode = Node(data)
        if self.head is None:
            self.head = newNode
        else:
            newNode.next = self.head
            self.head = newNode

# Helper function to reverse the list
def reverse(Head):
    if Head is None:
        return Head

    prev = None
    curr = Head

    while curr:
        temp = curr.next
        curr.next = prev
        prev = curr
        curr = temp

    return prev

# Function to add two lists
def listSum(l1, l2):
    if l1 is None:
        return l1
    if l2 is None:
        return l2

    # Reverse first list
    l1 = reverse(l1)

    # Reverse second list
    l2 = reverse(l2)

    # Storing head whose reverse is to be returned
    head = l1
    prev = None
    c = 0
    sum = 0

    while l1 is not None and l2 is not None:
        sum = c + l1.data + l2.data
        l1.data = sum % 10
        c = sum // 10
        prev = l1
        l1 = l1.next
        l2 = l2.next

    if l1 is not None or l2 is not None:
        if l2 is not None:
            prev.next = l2
        l1 = prev.next

        while l1 is not None:
            sum = c + l1.data
            l1.data = sum % 10
            c = sum // 10
            prev = l1
            l1 = l1.next

    if c > 0:
        prev.next = Node(c)

    return reverse(head)

# Driver code
linkedList1 = LinkedList()
linkedList1.insert(3)
linkedList1.insert(4)
linkedList1.insert(5)

linkedList2 = LinkedList()
linkedList2.insert(1)
linkedList2.insert(2)
linkedList2.insert(3)

print("Linked List 1:")
print(linkedList1.traverse())

print("Linked List 2:")
print(linkedList2.traverse())

linkedList3 = LinkedList()
linkedList3.head = listSum(linkedList1.head, linkedList2.head)

print("Result Linked List after addition:")
print(linkedList3.traverse())
# Out:
# Linked List 1:
# 5 -> 4 -> 3 -> NULL
# Linked List 2:
# 3 -> 2 -> 1 -> NULL
# Result Linked List after addition:
# 8 -> 6 -> 4 -> NULL

# %% [markdown]
# This Python code adds two numbers represented by linked lists where the digits are stored in reverse order.
#
# Here’s a detailed explanation:
#
# 1.Node and LinkedList Classes:
#
# 1.1.Node: Each node stores a digit and a link to the next node.
#
# 1.2.LinkedList:
#
# 1.2.1.insert(data): Inserts a new node at the beginning of the list.
#
# 1.2.2.traverse(): Returns a string representation of the list for printing.
#
# 2.Reversing the List:
#
# 2.1.reverse(Head):
#
# 2.1.1.Reverses the linked list to facilitate addition.
#
# 2.1.2.Uses three pointers: prev, curr, and temp to reverse the links.
#
# 3.Adding Two Linked Lists:
#
# 3.1.listSum(l1, l2):
#
# 3.1.1.Reverses both linked lists to align the digits for addition.
#
# 3.1.2.Adds corresponding nodes, handles carry over, and creates a new list for the result.
#
# 3.1.3.If one list is longer, continues to process the remaining nodes.
#
# 3.1.4.If there's a carry left after processing all nodes, it creates a new node with the carry value.
#
# 4.Example Usage:
#
# 4.1.Linked List 1: 3 -> 4 -> 5 (represents 543)
#
# 4.2.Linked List 2: 1 -> 2 -> 3 (represents 321)
#
# 5.Result:
#
# 5.1.The lists are reversed: 5 -> 4 -> 3 and 3 -> 2 -> 1.
#
# 5.2.Added digit by digit with carry handling, resulting in 8 -> 6 -> 4 (representing 864).
#
# 5.3.The result list is reversed back to 4 -> 6 -> 8.

# %%
# Question 10
# 10. Clone a Linked List with next and Random Pointer
# Given a linked list of size N where each node has two links: one pointer points to the next node and the
# second pointer points to any node in the list. The task is to create a clone of this linked list in O(N) time. 
class Node:
    def __init__(self, value=0, next=None, random=None):
        self.value = value
        self.next = next
        self.random = random

def clone_linked_list(head):
    if not head:
        return None

    # Step 1: Insert new nodes
    current = head
    while current:
        new_node = Node(current.value, current.next)
        current.next = new_node
        current = new_node.next

    # Step 2: Set random pointers for the new nodes
    current = head
    while current:
        new_node = current.next
        new_node.random = current.random.next if current.random else None
        current = new_node.next

    # Step 3: Separate the original and cloned lists
    original = head
    clone_head = head.next
    clone_current = clone_head

    while original:
        original.next = clone_current.next
        original = original.next
        if original:
            clone_current.next = original.next
        clone_current = clone_current.next

    return clone_head

def print_list(head):
    current = head
    while current:
        random_val = current.random.value if current.random else None
        print(f"Value: {current.value}, Random: {random_val}")
        current = current.next

# Example usage
# Creating a linked list: 1 -> 2 -> 3 -> 4 -> 5

# Initialize nodes
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)
head.next.next.next.next = Node(5)

# Set up random pointers
head.random = head.next.next.next  # 1 -> 4
head.next.random = head.next.next  # 2 -> 3
head.next.next.random = head  # 3 -> 1
head.next.next.next.random = head.next.next.next.next  # 4 -> 5
head.next.next.next.next.random = head.next.next  # 5 -> 3

# Clone the linked list
cloned_head = clone_linked_list(head)

# Print original and cloned lists
print("Original List:")
print_list(head)

print("\nCloned List:")
print_list(cloned_head)
# Out:
# Original List:
# Value: 1, Random: 4
# Value: 2, Random: 3
# Value: 3, Random: 1
# Value: 4, Random: 5
# Value: 5, Random: 3
#
# Cloned List:
# Value: 1, Random: 4
# Value: 2, Random: 3
# Value: 3, Random: 1
# Value: 4, Random: 5
# Value: 5, Random: 3

# %% [markdown]
# This Python code clones a linked list where each node has two pointers: next and random. The task is to create a deep copy of the list such that each node in the cloned list corresponds to a node in the original list, with the same next and random pointers.
#
# Here's an explanation of the code:
#
# 1.Node Class:
# Represents each node in the linked list with value, next, and random pointers.
#
# 2.Clone Linked List Function:
#
# 2.1.Step 1: Insert New Nodes:
#
# 2.1.1.Traverse the original list and create a new node for each existing node.
#
# 2.1.2.Insert each new node immediately after its corresponding original node.
#
# 2.1.3.Example: For a node A with value 1, a new node A' with value 1 is inserted right after A.
#
# 2.2.Step 2: Set Random Pointers:
#
# 2.2.1.Traverse the list again and set the random pointers for the new nodes.
#
# 2.2.2.The random pointer of a new node A' is set to the node following the random pointer of the original node A.
#
# 2.2.3.Example: If A.random points to node B, then A'.random points to B'.
#
# 2.3.Step 3: Separate Original and Cloned Lists:
#
# 2.3.1.Restore the next pointers of the original list to their original state.
#
# 2.3.2.Extract the cloned list by updating the next pointers of the new nodes.
#
# 2.3.3.Example: If A is the original node and A' is the cloned node, A.next is updated to point to the next original node, and A'.next is updated to point to the next cloned node.
#
# 3.Print List Function:
# Prints each node's value and the value of its random pointer, helping to verify the correctness of the cloning process.
#
# 4.Example Usage:
#
# 4.1.Creating the Linked List:
#
# 4.1.1.Initializes nodes and sets up next and random pointers.
#
# 4.1.2.The random pointers are set to arbitrary nodes as shown in the code comments.
#
# 4.2.Cloning the Linked List:
# The clone_linked_list function is called to create a deep copy of the list.
#
# 4.3.Printing Lists:
# Prints the original and cloned lists to verify that the cloned list matches the original list in structure and random pointers.
